# %% [markdown]
# <div style="border:solid green 2px; padding: 20px">
#
# <b>Анна, привет!</b> Мы рады тебя видеть на территории код-ревьюеров 😎. Ты проделала большую работу над проектом, но давай познакомимся и сделаем его еще лучше! У нас тут своя атмосфера и несколько правил:
#
#
# 1. Меня зовут Александр Матвеевский. Я работаю код-ревьюером, моя основная цель — не указать на совершенные тобою ошибки, а поделиться своим опытом и помочь тебе стать дата-специалистом.
# 2. Общаемся на ты.
# 3. Если хочешь написать, спросить - не нужно стесняться. Только выбери свой цвет для комментария.
# 4. Это учебный проект, тут можно не бояться сделать ошибку.
# 5. У нас с тобой 6 попыток для сдачи проекта.
# 6. Let's Go!
#
# ---
#
# Я буду красить комментарии цветом, пожалуйста, не удаляй их:
#
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №1__
#
# Такой комментарий нужно исправить обязательно, он критически влияет на удачное выполнение проекта.
# </div>
#
# ---
#
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
#
# Такой комментарий является рекомендацией или советом. Можешь использовать их на своё усмотрение.
# </div>
#
# ---
#
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Такой комментарий  говорит о том, что было сделано что-то качественное и правильное =)
# </div>
#
# ---
#
# Предлагаю работать над проектом в диалоге: если ты что-то меняешь в проекте или отвечаешь на мои комментарии — пиши об этом. Мне будет легче отследить изменения, если ты выделишь свои комментарии:
#
# <div class="alert alert-info"> <b>Комментарии студента:</b> Например, вот так.</div>
#
# Всё это поможет выполнить повторную проверку твоего проекта оперативнее. Если будут какие-нибудь вопросы по моим комментариям, пиши, будем разбираться вместе :)
#
# ---

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарии студента:</b> Добрый день, Александр! Спасибо за проверку моего проекта и подробные комментарии. По мере внесения правок я буду оставлять соответствующие комментарии.</div>

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №2__
#
# Анна, рад тебя видеть =) Спасибо тебе за обратную связь и правки ^^
# </div>

# %% [markdown]
# # Анализ убытков развлекательного приложения Procrastinate Pro+
#
# Развлекательное приложение Procrastinate Pro+ терпит ежемесячные убытки, несмотря на крупные рекламные вложения. Необходимо разобраться в причинах убытков и предложить шаги для выхода из кризиса.
#
# Нам доступны данные о пользователях приложения, их покупках и рекламных кампаниях, проведенных для привлечения пользователей.
#
# Период сбора данных - с 1 мая по 27 октября 2019 года.
#
# <b>Цели исследования</b>
#
# 1. Определить уровень окупаемости рекламы в целом.
# 2. Установить устройства, страны и рекламные каналы, которые могут оказывать негативное влияние на окупаемость рекламы.
# 3. Найти причины проблем окупаемости.
#
# <b>Основные задачи</b>
#
# 1. Определить, откуда приходят пользователи и какими устройствами они пользуются.
# 2. Найти стоимость привлечения пользователей из различных рекламных каналов.
# 3. Посчитать, сколько денег приносит каждый клиент.
# 4. Понять, когда расходы на привлечение клиента окупаются.
# 5. Определить, какие факторы мешают привлечению клиентов.
#
# <b>Ход исследования</b>
#
# 1. Загрузка, обзор, предобработка данных.
# 2. Подготовка функций.
# 3. Исследовательский анализ данных.
# 4. Базовая оценка маркетинговых усилий.
# 5. Оценка окупаемости рекламы.
# 6. Оценка удержания и конверсии.
# 7. Выводы и рекомендации.

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
#
# Отличная практика - расписывать цель и основные этапы своими словами (этот навык очень поможет на фильнальном проекте). Хорошо было бы добавить ход и цель исследования. Вот мой личный пример:
#
# ![image.png](attachment:image.png)
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарии студента:</b> Готово.</div>

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №2__
#
# Супер, старайся, пожалуйста, придерживаться этой стратегии в дальнейших проектах =)
# </div>

# %% [markdown]
# ## Загрузка и обзор данных

# %%
# импортирование библиотек
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
from matplotlib import pyplot as plt

# %%
# чтение данных
try:
    visits = pd.read_csv('visits_info_short.csv')
    orders = pd.read_csv('orders_info_short.csv')
    ad_costs = pd.read_csv('costs_info_short.csv')
except:
    visits = pd.read_csv('/datasets/visits_info_short.csv')
    orders = pd.read_csv('/datasets/orders_info_short.csv')
    ad_costs = pd.read_csv('/datasets/costs_info_short.csv')

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №1__
#
# Кажется, работа над проектом велась локально и пути к файлам не были изменены на общедоступные. Стоит переписать код таким образом, что бы он запускался и в jupiter hub, и локально без внесения дополнительных правок. Этого можно добиться многими способами. Например, использовать конструкцию try-except для путей файлов: try - пути на локальном компьютере, except - пути на сервере. Или применить библиотеку os:
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарии студента:</b> Готово.</div>

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
#
# __Комментарий от ревьюера №2__
#
# Здорово, что для подгрузки данных используешь конструкцию `try-except`, она поможет избежать потенциальных ошибок при загрузке данных, связанных, например, с некорректным указанием путей.
#
# Подробнее о конструкции по ссылке:
#
# https://pythonworld.ru/tipy-dannyx-v-python/isklyucheniya-v-python-konstrukciya-try-except-dlya-obrabotki-isklyuchenij.html
#
# Либо же можно использовать стандартную библиотеку os:
#
# https://pythonworld.ru/moduli/modul-os.html
#
#
# Несколько интересных статей кейсы использования конструкции:
#
# https://www.programiz.com/python-programming/exception-handling
#
# https://towardsdatascience.com/do-not-abuse-try-except-in-python-d9b8ee59e23b
#
# https://www.techbeamers.com/use-try-except-python/
#
# Как вариант в try можно указать корректные пути (в нашем случае глобальные) в except - некорректные (локальные). Можно также специфицровать тип ошибки, FileNotFoundError или задать кастомный тип ошибки (FilePathError, например)
#
# Она полезна, если ты работаешь локально, а потом подгружаешь проект на платформу. Конструкция позволит не падать коду и локально, и на сервере ЯП, так как если не сработает один блок с путями, сработает другой.
#
# Ну и вообще, в целом полезно про эту констуркцию знать, она универсальна и может быть использована в разных задачах.

# %%
# обзор данных
display(visits.info())
display(orders.info())
ad_costs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309901 entries, 0 to 309900
# Data columns (total 6 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   User Id        309901 non-null  int64
#  1   Region         309901 non-null  object
#  2   Device         309901 non-null  object
#  3   Channel        309901 non-null  object
#  4   Session Start  309901 non-null  object
#  5   Session End    309901 non-null  object
# dtypes: int64(1), object(5)
# memory usage: 14.2+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40212 entries, 0 to 40211
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   User Id   40212 non-null  int64
#  1   Event Dt  40212 non-null  object
#  2   Revenue   40212 non-null  float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 942.6+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# ...

# %%
# проверка на дубликаты
visits.duplicated().sum()
# Out:
# 0

# %%
orders.duplicated().sum()
# Out:
# 0

# %%
ad_costs.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## Предобработка данных

# %%
# приведение названий колонок к единообразию
visits = visits.rename(columns = {'User Id' : 'user_id', 'Region' : 'region', 'Device' : 'device', 'Channel' : 'channel', 'Session Start' : 'session_start', 'Session End' : 'session_end'})
visits.columns
# Out:
# Index(['user_id', 'region', 'device', 'channel', 'session_start',
#        'session_end'],
#       dtype='object')

# %%
orders = orders.rename(columns = {'User Id' : 'user_id', 'Event Dt' : 'event_dt', 'Revenue' : 'revenue'})
orders.columns
# Out:
# Index(['user_id', 'event_dt', 'revenue'], dtype='object')

# %%
ad_costs = ad_costs.rename(columns = {'Channel' : 'channel'})
ad_costs.columns
# Out:
# Index(['dt', 'channel', 'costs'], dtype='object')

# %%
# изменение типов данных
visits['session_start'] = pd.to_datetime(visits['session_start'])
visits['session_end'] = pd.to_datetime(visits['session_end'])
orders['event_dt'] = pd.to_datetime(orders['event_dt'])
ad_costs['dt'] = pd.to_datetime(ad_costs['dt'])
ad_costs['dt'] = ad_costs['dt'].dt.date
ad_costs['dt'] = ad_costs['dt'].astype('datetime64[D]')

# %%
# проверка изменения типов данных
display(visits.info())
display(orders.info())
ad_costs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309901 entries, 0 to 309900
# Data columns (total 6 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   user_id        309901 non-null  int64
#  1   region         309901 non-null  object
#  2   device         309901 non-null  object
#  3   channel        309901 non-null  object
#  4   session_start  309901 non-null  datetime64[ns]
#  5   session_end    309901 non-null  datetime64[ns]
# dtypes: datetime64[ns](2), int64(1), object(3)
# memory usage: 14.2+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40212 entries, 0 to 40211
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   user_id   40212 non-null  int64
#  1   event_dt  40212 non-null  datetime64[ns]
#  2   revenue   40212 non-null  float64
# dtypes: datetime64[ns](1), float64(1), int64(1)
# memory usage: 942.6 KB
# None
# ...

# %%
# проверка и коррекция временнОго интервала для посещений
display(visits['session_start'].min())
visits['session_start'].max()
# Out:
# Timestamp('2019-05-01 00:00:41')
# Timestamp('2019-10-31 23:59:23')

# %%
visits = visits.query('session_start < "2019-10-28 00:00:00"')
display(visits['session_start'].min())
visits['session_start'].max()
# Out:
# Timestamp('2019-05-01 00:00:41')
# Timestamp('2019-10-27 23:59:04')

# %%
# проверка и коррекция временнОго интервала для покупок
display(orders['event_dt'].min())
orders['event_dt'].max()
# Out:
# Timestamp('2019-05-01 00:28:11')
# Timestamp('2019-10-31 23:56:56')

# %%
orders = orders.query('event_dt < "2019-10-28 00:00:00"')
display(orders['event_dt'].min())
orders['event_dt'].max()
# Out:
# Timestamp('2019-05-01 00:28:11')
# Timestamp('2019-10-27 23:55:15')

# %%
# проверка и временнОго интервала для рекламных кампаний
display(ad_costs['dt'].min())
ad_costs['dt'].max()
# Out:
# Timestamp('2019-05-01 00:00:00')
# Timestamp('2019-10-27 00:00:00')

# %%
# проверка ошибок начала / окончания сессий
visits.query('session_start > session_end')
# Out:
# Empty DataFrame
# Columns: [user_id, region, device, channel, session_start, session_end]
# Index: []

# %%
# проверка численных данных
display(orders['revenue'].describe())
ad_costs['costs'].describe()
# Out:
# count    39125.000000
# mean         5.373233
# std          3.478018
# min          4.990000
# 25%          4.990000
# 50%          4.990000
# 75%          4.990000
# max         49.990000
# Name: revenue, dtype: float64
# count    1800.000000
# mean       58.609611
# std       107.740223
# min         0.800000
# 25%         6.495000
# 50%        12.285000
# 75%        33.600000
# max       630.000000
# Name: costs, dtype: float64

# %% [markdown]
# Данные не содержат полных дубликатов, ошибок начала / окончания сессий, а также очевидно некорректных численных значений.
#
# Удалены строки, описывающие события, произошедшие после 27 октября 2019.
#
# Именование столбцов во всех трех таблицах приведено к единообразию и принятым правилам именования столбцов. Для столбцов, содержащих время и дату, соответствующим образом изменен тип данных.
#
# В целом качество данных может быть оценено как высокое.

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
#
# Хорошо, основные действия по предобработке сделаны, здорово, что ты не забыли проверить данные на наличие дубликатов.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
#
#
# * если мы только привели преобразование в строчные символы и заменили пробел на знак `_`, то мы можем использовать такой подход:
#
# `visits.columns = visits.columns.str.lower().str.replace(' ', '_')`
#
# также интересным является подход с использованием list comprehensions:
#
# `visits.columns = [x.lower().replace(' ', '_') for x in visits.columns.values]`
#
# * на стадии загрузки и подготовки данных к исследовательскому анализу, советую посмотреть на данные более детально, чтобы избежать невынужденных ошибок в дальнейшем. Чем большем мы знаем о данных - тем более корректны и обоснованы выглядят наши выводы. Такие проверки много времени не занимают, но зато мы можем лучше контролировать данные и их анализ. Например, мы можем:
#     - проверить временной интервал на соответствие условию проекта, а также на возможные ошибки (например, проверить случаи, когда окончание сессии было раньше, и так далее);
#     - для численных данных посмотреть на их статистические показатели и проверить их на наличие каких-то ошибок или аномалий (например, нули или отрицательные значения там, где они не должны быть).

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарии студента:</b> Выполнены проверки на соответствие временному интервалу, на ошибки начала / окончание сессии, а также проверка численных значений.</div>

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №2__
#
#
# Рад, что воспользовалась ^^

# %% [markdown]
# ## Подготовка функций для анализа

# %%
# формирование функции для получения профилей пользователей
def get_profiles(visits, orders, ad_costs):

    # находим параметры первых посещений
    profiles = (
        visits.sort_values(by=['user_id', 'session_start'])
        .groupby('user_id')
        .agg(
            {
            'session_start': 'first',
            'channel': 'first',
            'device': 'first',
            'region': 'first',
            }
        )
        .rename(columns={'session_start': 'first_ts'})
        .reset_index()
    )
# для когортного анализа определяем дату первого посещения
# и первый день месяца, в который это посещение произошло
    profiles['dt'] = profiles['first_ts'].dt.date
    profiles['dt'] = profiles['dt'].astype('datetime64[D]')
    profiles['acquisition_month'] = profiles['first_ts'].astype('datetime64[M]')

# добавляем признак платящих пользователей
    profiles['payer'] = profiles['user_id'].isin(orders['user_id'].unique())

# считаем количество уникальных пользователей
# с одинаковыми источником и датой привлечения
    new_users = (
        profiles.groupby(['dt', 'channel'])
        .agg({'user_id': 'nunique'})
        .rename(columns={'user_id': 'unique_users'})
        .reset_index()
        )
# объединяем траты на рекламу и число привлечённых пользователей
    ad_costs = ad_costs.merge(new_users, on=['dt', 'channel'], how='left')
# делим рекламные расходы на число привлечённых пользователей
    ad_costs['acquisition_cost'] = ad_costs['costs'] / ad_costs['unique_users']
# добавляем стоимость привлечения в профили
    profiles = profiles.merge(
        ad_costs[['dt', 'channel', 'acquisition_cost']],
        on=['dt', 'channel'],
        how='left',
    )
# стоимость привлечения органических пользователей равна нулю
    profiles['acquisition_cost'] = profiles['acquisition_cost'].fillna(0)
    
    return profiles

# %%
# формирование функции для получения Retention Rate
def get_retention(profiles, visits, observation_date, horizon_days, dimensions = [], ignore_horizon = False):
    
# добавляем столбец payer в передаваемый dimensions список
    dimensions = ['payer'] + dimensions

# исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1)
        
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')

# собираем «сырые» данные для расчёта удержания
    result_raw = result_raw.merge(
        visits[['user_id', 'session_start']], on='user_id', how='left'
    )
    result_raw['lifetime'] = (
        result_raw['session_start'] - result_raw['first_ts']
    ).dt.days
# функция для группировки таблицы по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        result = df.pivot_table(
            index=dims, columns='lifetime', values='user_id', aggfunc='nunique'
        )
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        result = result.div(result['cohort_size'], axis=0)
        result = result[['cohort_size'] + list(range(horizon_days))]
        result['cohort_size'] = cohort_sizes
        return result

# получаем таблицу удержания
    result_grouped = group_by_dimensions(result_raw, dimensions, horizon_days)

# получаем таблицу динамики удержания
    result_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

# возвращаем обе таблицы и сырые данные
    return result_raw, result_grouped, result_in_time

# %%
# функция для расчёта конверсии

def get_conversion(profiles, orders, observation_date, horizon_days, dimensions=[], ignore_horizon=False,):

# исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')

# определяем дату и время первой покупки для каждого пользователя
    first_purchases = (
        orders.sort_values(by=['user_id', 'event_dt'])
        .groupby('user_id')
        .agg({'event_dt': 'first'})
        .reset_index()
    )

# добавляем данные о покупках в профили
    result_raw = result_raw.merge(
        first_purchases[['user_id', 'event_dt']], on='user_id', how='left'
    )

# рассчитываем лайфтайм для каждой покупки
    result_raw['lifetime'] = (
        result_raw['event_dt'] - result_raw['first_ts']
    ).dt.days

# группируем по cohort, если в dimensions ничего нет
    if len(dimensions) == 0:
        result_raw['cohort'] = 'All users' 
        dimensions = dimensions + ['cohort']

# функция для группировки таблицы по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        result = df.pivot_table(
            index=dims, columns='lifetime', values='user_id', aggfunc='nunique'
        )
        result = result.fillna(0).cumsum(axis = 1)
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
# делим каждую «ячейку» в строке на размер когорты
# и получаем conversion rate
        result = result.div(result['cohort_size'], axis=0)
        result = result[['cohort_size'] + list(range(horizon_days))]
        result['cohort_size'] = cohort_sizes
        return result

# получаем таблицу конверсии
    result_grouped = group_by_dimensions(result_raw, dimensions, horizon_days)

# для таблицы динамики конверсии убираем 'cohort' из dimensions
    if 'cohort' in dimensions: 
        dimensions = []

# получаем таблицу динамики конверсии
    result_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

# возвращаем обе таблицы и сырые данные
    return result_raw, result_grouped, result_in_time

# %%
# функция для расчёта LTV и ROI

def get_ltv(profiles, orders, observation_date, horizon_days, dimensions=[], ignore_horizon=False,):

# исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')
# добавляем данные о покупках в профили
    result_raw = result_raw.merge(
        orders[['user_id', 'event_dt', 'revenue']], on='user_id', how='left'
    )
# рассчитываем лайфтайм пользователя для каждой покупки
    result_raw['lifetime'] = (
        result_raw['event_dt'] - result_raw['first_ts']
    ).dt.days
# группируем по cohort, если в dimensions ничего нет
    if len(dimensions) == 0:
        result_raw['cohort'] = 'All users'
        dimensions = dimensions + ['cohort']

# функция группировки по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
# строим «треугольную» таблицу выручки
        result = df.pivot_table(
            index=dims, columns='lifetime', values='revenue', aggfunc='sum'
        )
# находим сумму выручки с накоплением
        result = result.fillna(0).cumsum(axis=1)
# вычисляем размеры когорт
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
# объединяем размеры когорт и таблицу выручки
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
# считаем LTV: делим каждую «ячейку» в строке на размер когорты
        result = result.div(result['cohort_size'], axis=0)
# исключаем все лайфтаймы, превышающие горизонт анализа
        result = result[['cohort_size'] + list(range(horizon_days))]
# восстанавливаем размеры когорт
        result['cohort_size'] = cohort_sizes

# собираем датафрейм с данными пользователей и значениями CAC, 
# добавляя параметры из dimensions
        cac = df[['user_id', 'acquisition_cost'] + dims].drop_duplicates()

# считаем средний CAC по параметрам из dimensions
        cac = (
            cac.groupby(dims)
            .agg({'acquisition_cost': 'mean'})
            .rename(columns={'acquisition_cost': 'cac'})
        )

# считаем ROI: делим LTV на CAC
        roi = result.div(cac['cac'], axis=0)

# удаляем строки с бесконечным ROI
        roi = roi[~roi['cohort_size'].isin([np.inf])]

# восстанавливаем размеры когорт в таблице ROI
        roi['cohort_size'] = cohort_sizes

# добавляем CAC в таблицу ROI
        roi['cac'] = cac['cac']

# в финальной таблице оставляем размеры когорт, CAC
# и ROI в лайфтаймы, не превышающие горизонт анализа
        roi = roi[['cohort_size', 'cac'] + list(range(horizon_days))]

# возвращаем таблицы LTV и ROI
        return result, roi

# получаем таблицы LTV и ROI
    result_grouped, roi_grouped = group_by_dimensions(
        result_raw, dimensions, horizon_days
    )

# для таблиц динамики убираем 'cohort' из dimensions
    if 'cohort' in dimensions:
        dimensions = []

# получаем таблицы динамики LTV и ROI
    result_in_time, roi_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    return (
        result_raw,  # сырые данные
        result_grouped,  # таблица LTV
        result_in_time,  # таблица динамики LTV
        roi_grouped,  # таблица ROI
        roi_in_time,  # таблица динамики ROI
    )

# %%
# функция для сглаживания фрейма

def filter_data(df, window):
    
# для каждого столбца применяем скользящее среднее
    for column in df.columns.values:
        df[column] = df[column].rolling(window).mean() 
    return df

# %%
# функция для визуализации удержания

def plot_retention(retention, retention_history, horizon, window=7):

# задаём размер сетки для графиков
    plt.figure(figsize=(15, 10))

# исключаем размеры когорт и удержание первого дня
    retention = retention.drop(columns=['cohort_size', 0])
# в таблице динамики оставляем только нужный лайфтайм
    retention_history = retention_history.drop(columns=['cohort_size'])[
        [horizon - 1]
    ]

# если в индексах таблицы удержания только payer,
# добавляем второй признак — cohort
    if retention.index.nlevels == 1:
        retention['cohort'] = 'All users'
        retention = retention.reset_index().set_index(['cohort', 'payer'])

# в таблице графиков — два столбца и две строки, четыре ячейки
# в первой строим кривые удержания платящих пользователей
    ax1 = plt.subplot(2, 2, 1)
    retention.query('payer == True').droplevel('payer').T.plot(
        grid=True, ax=ax1
    )
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Удержание платящих пользователей')

# во второй ячейке строим кривые удержания неплатящих
# вертикальная ось — от графика из первой ячейки
    ax2 = plt.subplot(2, 2, 2, sharey=ax1)
    retention.query('payer == False').droplevel('payer').T.plot(
        grid=True, ax=ax2
    )
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Удержание неплатящих пользователей')

# в третьей ячейке — динамика удержания платящих
    ax3 = plt.subplot(2, 2, 3)
# получаем названия столбцов для сводной таблицы
    columns = [
        name
        for name in retention_history.index.names
        if name not in ['dt', 'payer']
    ]
# фильтруем данные и строим график
    filtered_data = retention_history.query('payer == True').pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax3)
    plt.xlabel('Дата привлечения')
    plt.title(
        'Динамика удержания платящих пользователей на {}-й день'.format(
            horizon
        )
    )

# в чётвертой ячейке — динамика удержания неплатящих
    ax4 = plt.subplot(2, 2, 4, sharey=ax3)
# фильтруем данные и строим график
    filtered_data = retention_history.query('payer == False').pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax4)
    plt.xlabel('Дата привлечения')
    plt.title(
        'Динамика удержания неплатящих пользователей на {}-й день'.format(
            horizon
        )
    )
    
    plt.tight_layout()
    plt.show()

# %%
# функция для визуализации конверсии

def plot_conversion(conversion, conversion_history, horizon, window=7):

# задаём размер сетки для графиков
    plt.figure(figsize=(15, 5))

# исключаем размеры когорт
    conversion = conversion.drop(columns=['cohort_size'])
# в таблице динамики оставляем только нужный лайфтайм
    conversion_history = conversion_history.drop(columns=['cohort_size'])[
        [horizon - 1]
    ]

# первый график — кривые конверсии
    ax1 = plt.subplot(1, 2, 1)
    conversion.T.plot(grid=True, ax=ax1)
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Конверсия пользователей')

# второй график — динамика конверсии
    ax2 = plt.subplot(1, 2, 2, sharey=ax1)
    columns = [
# столбцами сводной таблицы станут все столбцы индекса, кроме даты
        name for name in conversion_history.index.names if name not in ['dt']
    ]
    filtered_data = conversion_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax2)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика конверсии пользователей на {}-й день'.format(horizon))

    plt.tight_layout()
    plt.show()

# %%
# функция для визуализации LTV и ROI

def plot_ltv_roi(ltv, ltv_history, roi, roi_history, horizon, window=7):

# задаём сетку отрисовки графиков
    plt.figure(figsize=(20, 10))

# из таблицы ltv исключаем размеры когорт
    ltv = ltv.drop(columns=['cohort_size'])
    # в таблице динамики ltv оставляем только нужный лайфтайм
    ltv_history = ltv_history.drop(columns=['cohort_size'])[[horizon - 1]]

# стоимость привлечения запишем в отдельный фрейм
    cac_history = roi_history[['cac']]

# из таблицы roi исключаем размеры когорт и cac
    roi = roi.drop(columns=['cohort_size', 'cac'])
# в таблице динамики roi оставляем только нужный лайфтайм
    roi_history = roi_history.drop(columns=['cohort_size', 'cac'])[
        [horizon - 1]
    ]

# первый график — кривые ltv
    ax1 = plt.subplot(2, 3, 1)
    ltv.T.plot(grid=True, ax=ax1)
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('LTV')

# второй график — динамика ltv
    ax2 = plt.subplot(2, 3, 2, sharey=ax1)
# столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in ltv_history.index.names if name not in ['dt']]
    filtered_data = ltv_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax2)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика LTV пользователей на {}-й день'.format(horizon))

# третий график — динамика cac
    ax3 = plt.subplot(2, 3, 3, sharey=ax1)
# столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in cac_history.index.names if name not in ['dt']]
    filtered_data = cac_history.pivot_table(
        index='dt', columns=columns, values='cac', aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax3)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика стоимости привлечения пользователей')

# четвёртый график — кривые roi
    ax4 = plt.subplot(2, 3, 4)
    roi.T.plot(grid=True, ax=ax4)
    plt.axhline(y=1, color='red', linestyle='--', label='Уровень окупаемости')
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('ROI')

# пятый график — динамика roi
    ax5 = plt.subplot(2, 3, 5, sharey=ax4)
# столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in roi_history.index.names if name not in ['dt']]
    filtered_data = roi_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax5)
    plt.axhline(y=1, color='red', linestyle='--', label='Уровень окупаемости')
    plt.xlabel('Дата привлечения')
    plt.title('Динамика ROI пользователей на {}-й день'.format(horizon))

    plt.tight_layout()
    plt.show()

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Хорошо, все необходимые функции были заданы, можно приступать к расчета и анализу👀

# %% [markdown]
# ## Исследовательский анализ данных

# %% [markdown]
# ### Профили пользователей

# %%
# создание профилей пользователей
profiles = get_profiles(visits, orders, ad_costs)
profiles['payer'] = profiles['payer'].replace(True, 1)
profiles['payer'] = profiles['payer'].replace(False, 0)
profiles.head()
# Out:
#     user_id            first_ts     channel  device         region         dt  \
# 0    599326 2019-05-07 20:58:57    FaceBoom     Mac  United States 2019-05-07
# 1   4919697 2019-07-09 12:46:07    FaceBoom  iPhone  United States 2019-07-09
# 2   6085896 2019-10-01 09:58:33     organic  iPhone         France 2019-10-01
# 3  22593348 2019-08-22 21:35:48  AdNonSense      PC        Germany 2019-08-22
# 4  31989216 2019-10-02 00:07:44     YRabbit  iPhone  United States 2019-10-02
#
#   acquisition_month  payer  acquisition_cost
# 0        2019-05-01      1          1.088172
# 1        2019-07-01      0          1.107237
# 2        2019-10-01      0          0.000000
# 3        2019-08-01      0          0.988235
# 4        2019-10-01      0          0.230769

# %% [markdown]
# ### Крайние даты привлечения пользователей

# %%
# определение min / max дат привлечения
min_date = profiles['dt'].min()
max_date = profiles['dt'].max()
display(min_date),
max_date
# Out:
# Timestamp('2019-05-01 00:00:00')
# Timestamp('2019-10-27 00:00:00')

# %% [markdown]
# Самое позднее привлечение пользователя произошло 27 октября. Это означает, что для анализа нам подходят пользователи, привлеченные не позднее 14 октября.

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
# Отсутствует вывод, иначе не совсем понятно, зачем мы смотрели на эти даты (например, соответствую ли даты ТЗ или нет).
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарии студента:</b> Готово.</div>

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №2__
#
# Не совсем так. Сравнить визуально с датами из ТЗ, и написать об этом в промежуточном выводе ![image.png](attachment:image.png)

# %% [markdown]
# ### Страны - источники пользователей

# %%
# определение стран - источников пользователей и доли платящих
country_breakdown = profiles.groupby('region').agg({'user_id': 'count', 'payer': 'sum',}).rename(columns={'user_id': 'user_quantity', 'payer' : 'payer_quantity'}).reset_index()
country_breakdown['payer_rate'] = country_breakdown['payer_quantity'] / country_breakdown['user_quantity'] * 100
country_breakdown = country_breakdown.drop(columns = 'payer_quantity')
country_breakdown
# Out:
#           region  user_quantity  payer_rate
# 0         France          17450    3.765043
# 1        Germany          14981    4.098525
# 2             UK          17575    3.926031
# 3  United States         100002    6.870863

# %% [markdown]
# Пользователи приходят из 4 стран - 3 европейские и Соединенные Штаты Америки. Больше всего платящих пользователей приходят из США, 7%.

# %% [markdown]
# ### Устройства пользователей

# %%
# определение устройств и доли платящих пользователей для устройств
device_breakdown = profiles.groupby('device').agg({'user_id': 'count', 'payer': 'sum',}).rename(columns={'user_id': 'user_quantity', 'payer' : 'payer_quantity'}).reset_index()
device_breakdown['payer_rate'] = device_breakdown['payer_quantity'] / country_breakdown['user_quantity'] * 100
device_breakdown = device_breakdown.drop(columns = 'payer_quantity')
device_breakdown
# Out:
#     device  user_quantity  payer_rate
# 0  Android          35032   11.667622
# 1      Mac          30042   12.709432
# 2       PC          30455    8.677098
# 3   iPhone          54479    3.366933

# %% [markdown]
# Пользователи заходят с устройств 4 типов. Самый многочисленный из них - iPhone, но платящих пользователей больше всего среди тех, у кого Android - почти 12%.

# %% [markdown]
# ### Рекламные каналы

# %%
# определение рекламных каналов и доли платящих пользователей для них
channel_breakdown = profiles.groupby('channel').agg({'user_id': 'count', 'payer': 'sum',}).rename(columns={'user_id': 'user_quantity', 'payer' : 'payer_quantity'}).reset_index()
channel_breakdown['payer_rate'] = channel_breakdown['payer_quantity'] / channel_breakdown['user_quantity'] * 100
channel_breakdown = channel_breakdown.drop(columns = 'payer_quantity').sort_values(by = 'payer_rate', ascending = False)
channel_breakdown
# Out:
#                channel  user_quantity  payer_rate
# 1             FaceBoom          29144   12.156876
# 0           AdNonSense           3880   11.262887
# 9       lambdaMediaAds           2149   10.330386
# 6               TipTop          19561    9.559838
# 5       RocketSuperAds           4448    7.868705
# 7       WahooNetBanner           8553    5.226236
# 8              YRabbit           4312    3.803340
# 3         MediaTornado           4364    3.574702
# 2              LeapBob           8553    3.016485
# 4   OppleCreativeMedia           8605    2.696107
# 10             organic          56439    2.042914

# %% [markdown]
# Наиболее продуктивный канал с точки зрения доли платящих пользователей - FaceBoom с результатом 12%.

# %% [markdown]
# ### Промежуточные выводы
# 1. Самая поздняя дата привлечения, подходящая для анализа - 14 октября.
# 2. Больше всего платящих пользователей приходят из США, 7%.
# 3. Самое популярное устройство - iPhone, но платящих пользователей больше всего с Android, 12%.
# 4. Наиболее продуктивный канал с точки зрения доли платящих пользователей - FaceBoom с результатом 12%.

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №1__
#
# Расчёт верный. Но нету общего вывода по разделу. Поправишь, пожалуйста, этот момент во всем проекте, чтобы дальше не акцентировать на этом внимаение?
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарии студента:</b> Готово.</div>

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №2__
#
#
# В целом в данном разделе был проведен хороший анализ данных - мы посмотрели на базовые значения конверсии пользователей в покупатели по регионам, устройствам и каналу привлечения, определили основной рынок. Получается, что больше всего приходит пользователей из США и они лучше других конвертируется. При этом большая часть пользователей заходит с мобильных устройств, это тоже стоит отметить. Также, мы можем сказать, что наибольшую конверсию имеют пользователи, которые пользуются Mac, а затем следуют пользователи iPhone, т.е. мы можем сказать, что в целом пользователи Apple имеют лучшую конверсию в покупателей. Возможно, тут есть плюсы ApplePay.

# %% [markdown]
# ## Маркетинг

# %% [markdown]
# ### Общая сумма рекламных расходов, $

# %%
total_ad_costs = ad_costs['costs'].sum()
round(total_ad_costs, 2)
# Out:
# 105497.3

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
# Лучше округлить до 1-2 знаков, после запятой
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарии студента:</b> Готово.</div>

# %% [markdown]
# ### Распределение рекламного бюджета по каналам привлечения

# %%
ad_costs_breakdown = ad_costs.pivot_table(index = 'channel', values = 'costs', aggfunc = 'sum').sort_values(by = 'costs', ascending = False).reset_index()
ad_costs_breakdown['percentage'] = ad_costs_breakdown['costs'] / total_ad_costs * 100
ad_costs_breakdown
# Out:
#               channel     costs  percentage
# 0              TipTop  54751.30   51.898295
# 1            FaceBoom  32445.60   30.754910
# 2      WahooNetBanner   5151.00    4.882589
# 3          AdNonSense   3911.25    3.707441
# 4  OppleCreativeMedia   2151.25    2.039152
# 5      RocketSuperAds   1833.00    1.737485
# 6             LeapBob   1797.60    1.703930
# 7      lambdaMediaAds   1557.60    1.476436
# 8        MediaTornado    954.48    0.904744
# 9             YRabbit    944.22    0.895018

# %% [markdown]
# Наиболее ресурсоемкими каналами стали TipTop и Faceboom (51% и 31% рекламного бюджета соответственно), а наименее - YRabbit (чуть менее 1%).

# %% [markdown]
# ### Динамика расходов в каждом источнике

# %%
# формирование таблиц для графиков
ad_costs['month'] = ad_costs['dt'].dt.month
ad_costs['week'] = ad_costs['dt'].dt.isocalendar().week
ad_costs_weekly_dynamic = ad_costs.pivot_table(index = 'week', columns = 'channel', values = 'costs', aggfunc = 'sum')
ad_costs_monthly_dynamic = ad_costs.pivot_table(index = 'month', columns = 'channel', values = 'costs', aggfunc = 'sum')

# %%
# построение графиков
ad_costs_weekly_dynamic.plot(grid=True, figsize=(15, 5),)
plt.xlabel('Недели')
plt.ylabel('Тыс. долл.')
plt.title('Кривые еженедельных рекламных расходов по каналам')
plt.show()

ad_costs_monthly_dynamic.plot(grid=True, figsize=(15, 5),)
plt.xlabel('Месяцы')
plt.ylabel('Тыс. долл.')
plt.title('Кривые ежемесячных рекламных расходов по каналам')
plt.show()

# %% [markdown]
# 1. С сентября расходы в каналах FaceBoom и TipTop начинают снижаться.
# 2. Расходы в других каналах не превышают 2000 долларов каждый.

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №1__
#
# Графики верны, но отсутствует их оформление ( подписи осей). Поправь, пожалуйста, этот момент во всем проекте. Чтобы дальше на этом не акцентировать внимание
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарии студента:</b> Готово, и добавила вывод о динамике расходов.</div>

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №2__
#
# Отличные и наглядные графики 👍
#
# Здорово, когда они подписаны. Так быстрее понять о чем идёт речь на нём.
#
# </div>

# %% [markdown]
# ### Среднее значение CAC
# #### Общее среднее значение CAC

# %%
avg_cac = profiles['acquisition_cost'].mean()
round(avg_cac, 2)
# Out:
# 0.7

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №2__
#
# Отличный инсайд для заказчика, молодец =)
#
# </div>

# %% [markdown]
# #### Среднее значение CAC для разных рекламных каналов

# %%
# расчет среднего CAC для разных рекламных каналов
avg_cac_per_channel = profiles.pivot_table(index = 'channel', values = 'acquisition_cost', aggfunc = 'mean').sort_values(by = 'acquisition_cost', ascending = False).reset_index()
avg_cac_per_channel = avg_cac_per_channel.rename(columns = {'acquisition_cost' : 'avg_cac'})
avg_cac_per_channel
# Out:
#                channel   avg_cac
# 0               TipTop  2.799003
# 1             FaceBoom  1.113286
# 2           AdNonSense  1.008054
# 3       lambdaMediaAds  0.724802
# 4       WahooNetBanner  0.602245
# 5       RocketSuperAds  0.412095
# 6   OppleCreativeMedia  0.250000
# 7              YRabbit  0.218975
# 8         MediaTornado  0.218717
# 9              LeapBob  0.210172
# 10             organic  0.000000

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
# Неплохо бы посчитать средний САС по проекту
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарии студента:</b> Готово.</div>

# %% [markdown]
# ### Промежуточные выводы
#
# 1. Общая сумма рекламных расходов за период составила 105497 долларов.
# 2. Наиболее ресурсоемкими каналами стали TipTop и Faceboom (51% и 31% рекламного бюджета соответственно), а наименее - YRabbit (чуть менее 1%).
# 3. В двух каналах-лидерах расходы росли до сентября, после чего стали медленно снижаться.
# 4. При этом в других каналах расходы оставались стабильно низкими, не превышая отметку 2000 долларов, на всем протяжении периода.
# 5. Самое высокое среднее значение CAC - в канале TipTop, почти 3 доллара, самое низкое среди платных каналов - в LeapBob (20 центов).

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Наиболее дорогостоящим каналом привлечения пользователей является TipTop, однако количество и доля платящих пользователей, приходящих с этого источника, не так высоки. Это можно объяснить молодой аудиторией TipTop'a и, соответственно, не очень высокой их платежеспособностью.
#
# </div>

# %% [markdown]
# ## Оценка окупаемости рекламы

# %% [markdown]
# ### Исключение органических пользователей из расчета
# Так как в данном исследовании нас интересует именно окупаемость рекламы, то для большей точности нам необходимо исключить органических пользователей из расчетов.

# %%
# исключение органических пользователей из таблицы профилей
profiles = profiles.query('channel != "organic"')

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №2__
#
# Совершенно верно, поскольку мы за них ничего не платим,  а нам нужно изучить именно окупаемость рекламы.
# </div>

# %% [markdown]
# ### Общая оценка LTV и ROI

# %%
# формирование таблиц LTV и ROI
observation_date = datetime(2019, 11, 1).date()
horizon = 14

result_raw, ltv, ltv_history, roi, roi_history = get_ltv(profiles, orders, observation_date, horizon, dimensions=[], ignore_horizon=False,)

# %%
# обзор таблиц LTV и ROI
display(ltv)
display(ltv_history)
display(roi)
roi_history
# Out:
#            cohort_size      0.0       1.0       2.0      3.0       4.0  \
# cohort
# All users        88644  0.34558  0.435754  0.504507  0.56109  0.611436
#
#                 5.0      6.0       7.0       8.0       9.0      10.0  \
# cohort
# All users  0.654368  0.69414  0.729778  0.764563  0.796271  0.825195
#
#                11.0      12.0      13.0
# cohort
# All users  0.850494  0.875751  0.899328
#             cohort_size       0.0       1.0       2.0       3.0       4.0  \
# dt
# 2019-05-01          390  0.294282  0.383846  0.435026  0.514359  0.565538
# 2019-05-02          323  0.324427  0.618235  0.664582  0.757276  0.803622
# 2019-05-03          346  0.305751  0.452861  0.568237  0.669191  0.943468
# 2019-05-04          457  0.471904  0.570175  0.624770  0.679365  0.876105
# 2019-05-05          438  0.232443  0.394429  0.417215  0.462785  0.496963
# ...                 ...       ...       ...       ...       ...       ...
# ...

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №1__
#
# Есть небольшая неточность, которая немного искажает общие данные: из расчетов нам следует исключить пользователей с органическим трафиком: `profiles = profiles.query('channel != "organic"')` - поскольку мы за них ничего не платим,  а нам нужно изучить именно окупаемость рекламы.

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарии студента:</b> Готово.</div>

# %%
# графики LTV и ROI и графики динамики LTV и ROI
plot_ltv_roi(ltv, ltv_history, roi, roi_history, horizon, window=14)

# %% [markdown]
# 1. Общий показатель ROI указывает на то, что в целом реклама не окупается, то есть суммы, уплаченные за рекламу, превышают суммы выручки.
# 2. Стоимость привлечения растет на всем протяжении исследуемого периода.
# 3. При расчете ROI для каждой когорты на 14 день этот показатель снижается на всем протяжении исследуемого периода и пересекает порог окупаемости в начале июня.
# 4. Пиковые значения LTV на 14 день отмечаются в тех когортах, у которых дата привлечения близка к середине месяца. Исключение - период середины октября.

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №2__
#
# Логика анализа верная, согласен с выводом. Наблюдаем, что динамика ROI за лайфтайм падает. При относительно стабильной динамике LTV, динамика САС растёт с мая по конец октября. Эту закономерность мы наблюдаем в динамике ROI, что при сильном увеличении САС, в равной степени падает динамика ROI пользователей.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №1__
#
# Поправь, пожалуйста, описание динамики изменения стоимости привлечения пользователей по каналам, устройствам и странам, когда будет проведена фильтрация органических пользователей.

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарии студента:</b> Здесь после отсечения органических пользователей выполнены правки выводов, а динамику стоимости привлечения по каналам, устройствам, странам заново опишу ниже, в разделах 1.6.5 - 1.6.7.</div>

# %% [markdown]
# ### Общая оценка удержания

# %%
# формирование таблиц удержания  и динамики удержания
retention_raw, retention, retention_history = get_retention(profiles, visits, observation_date, horizon, dimensions = [], ignore_horizon = False)

# %%
# обзор долей удержания и динамики удержания
display(retention)
retention_history
# Out:
#        cohort_size    0         1         2         3         4         5  \
# payer
# 0            81342  1.0  0.176895  0.086622  0.051843  0.033513  0.024698
# 1             7302  1.0  0.380992  0.292933  0.235552  0.210353  0.191454
#
#               6         7         8         9        10        11        12  \
# payer
# 0      0.018650  0.014212  0.011630  0.009417  0.007389  0.006208  0.005913
# 1      0.166941  0.156806  0.145029  0.134621  0.133114  0.119830  0.116406
#
#              13
# payer
# 0      0.004622
# 1      0.103396
#                   cohort_size    0         1         2         3         4  \
# payer dt
# 0     2019-05-01          358  1.0  0.212291  0.072626  0.061453  0.022346
#       2019-05-02          300  1.0  0.196667  0.103333  0.033333  0.030000
#       2019-05-03          315  1.0  0.180952  0.076190  0.066667  0.028571
#       2019-05-04          413  1.0  0.164649  0.101695  0.058111  0.024213
# ...

# %%
# графики удержания и динамики удержания
plot_retention(retention, retention_history, horizon, window=14)

# %% [markdown]
# 1. Удержание стабильно снижается и для платящих, и для неплатящих пользователей.
# 2. Удержание платящих пользователей на 14 день колеблется в пределах 8%.
# 3. Удержание неплатящих пользователей стабильно близко к нулю.

# %% [markdown]
# ### Общая оценка конверсии

# %%
# формирование таблиц конверсии и динамики конверсии
conversion_raw, conversion, conversion_history = get_conversion(profiles, orders, observation_date, horizon, dimensions=[], ignore_horizon=False,)

# %%
# обзор конверсии и динамики конверсии
display(conversion)
conversion_history
# Out:
#            cohort_size       0.0       1.0       2.0       3.0     4.0  \
# cohort
# All users        88644  0.058752  0.066321  0.069999  0.072571  0.0745
#
#                 5.0       6.0       7.0       8.0       9.0     10.0  \
# cohort
# All users  0.075775  0.076745  0.077591  0.078291  0.078934  0.07934
#
#                11.0      12.0      13.0
# cohort
# All users  0.079644  0.079859  0.080141
#             cohort_size       0.0       1.0       2.0       3.0       4.0  \
# dt
# 2019-05-01          390  0.058974  0.066667  0.071795  0.071795  0.076923
# 2019-05-02          323  0.058824  0.068111  0.068111  0.068111  0.068111
# 2019-05-03          346  0.057803  0.069364  0.075145  0.078035  0.083815
# 2019-05-04          457  0.070022  0.074398  0.076586  0.078775  0.085339
# 2019-05-05          438  0.036530  0.043379  0.047945  0.052511  0.052511
# ...                 ...       ...       ...       ...       ...       ...
# ...

# %%
# графики конверсии и динамики конверсии
plot_conversion(conversion, conversion_history, horizon, window=14)

# %% [markdown]
# 1. Общая конверсия стабильно растет в течение всего анализируемого периода.
# 2. Пиковые значения конверсии на 14 день отмечаются, как правило, в тех  когортах, которые были прислечены в середине месяца. Исключение - когорты середины сентября и середины октября.

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №2__
#
# Хорошо, анализ конверсии и удержания корректен

# %% [markdown]
# ### LVT и ROI с разбивкой по устройствам

# %%
# расчет LTV и ROI с разбивкой по устройствам
result_raw, ltv_device, ltv_history_device, roi_device, roi_history_device = get_ltv(profiles, orders, observation_date, horizon, dimensions=['device'], ignore_horizon=False,)
# графики LTV и ROI и графики динамики LTV и ROI
plot_ltv_roi(ltv_device, ltv_history_device, roi_device, roi_history_device, horizon, window=14)

# %% [markdown]
# 1. Самый высокий показатель CAC у тех пользователей, чьи устройства из категории Mac и iPhone.
# 2. Окупается - только на 11 день - только привлечение пользователей с PC.
# 3. Лучшую динамику ROI показывают пользователи PC, а худшую - Mac и iPhone.

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №2__
#
# С окупаемостью проблемы по всем устройствам кроме PC. Это значит, что у нас, по крайней мере, нет технических проблем, влияющих на монетизацию;
# </div>

# %% [markdown]
# ### LVT и ROI с разбивкой по странам

# %%
# расчет LTV и ROI с разбивкой по странам
result_raw, ltv_region, ltv_history_region, roi_region, roi_history_region = get_ltv(profiles, orders, observation_date, horizon, dimensions=['region'], ignore_horizon=False,)
# графики LTV и ROI и графики динамики LTV и ROI
plot_ltv_roi(ltv_region, ltv_history_region, roi_region, roi_history_region, horizon, window=14)

# %% [markdown]
# 1. Самый высокий LVT и LVT 14 дня у пользователей из  США.
# 2. Но и CAC этих пользователей несравнимо дороже, чем из всех других стран.
# 3. Привлечение пользователей из Великобритании, Германии и Франции окупается на 4 - 5 день.
# 4. Эти же страны показывают достойный ROI на 14 день.
# 5. Пользователи из США не окупают себя.

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №2__
#
# Все верно. Нужно разбираться детальнее с рекламой в США, тем более, что это наш основной рынок.

# %% [markdown]
# ### LVT и ROI с разбивкой по рекламным каналам

# %%
# расчет LTV и ROI с разбивкой по рекламным каналам
result_raw, ltv_channel, ltv_history_channel, roi_channel, roi_history_channel = get_ltv(profiles, orders, observation_date, horizon, dimensions=['channel'], ignore_horizon=False,)
# графики LTV и ROI и графики динамики LTV и ROI
plot_ltv_roi(ltv_channel, ltv_history_channel, roi_channel, roi_history_channel, horizon, window=14)

# %% [markdown]
# 1. Лучший LVT и LTV на 14 день показывают lambdaMediaAds и TipTop.
# 2. При этом самый высокий CAC именно у TipTop - выраженно дороже всех других каналов, а lambdaMediaAds только на 4 месте по стоимости.
# 3. Не окупается привлечение пользователей с помощью TipTop, FaceBoom и AdNonSense.
# 4. Каналы OpenCreativeMedia и RocketSuperAds окупаются на 5 день.
# 5. А все другие каналы окупают свою стоимость уже на 2 день.

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №2__
#
# Да, действительно, есть проблемы с каналом TipTop, видим значительный рост затрат на привлечение.
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарии студента:</b> Уточнила выводы для разделов 1.6.5 - 1.6.7.</div>

# %% [markdown]
# ### Промежуточные выводы
# 1. Реклама в целом не окупается.
# 2. Удержание снижается независимо от статуса (платящий / неплатящий пользователь), при этом для платящих удержание 14 дня колеблется от 8 до 14 процентов.
# 3. Общая конверсия 14 дн колеблется от 7,5 до 8,75 процентов.
# 4. Самый высокий показатель CAC у тех пользователей, чьи устройства из категории Mac и iPhone, самый низкий - у PC.
# 5. Окупается только привлечение пользователей с PC и то- на 11 день.
# 6. При этом самый высокий CAC именно у TipTop - выраженно дороже всех других каналов, а lambdaMediaAds только на 4 месте по стоимости.
# 7. Не окупается привлечение пользователей с помощью TipTop, FaceBoom и AdNonSense.
# 8. Каналы LeapBob, MediaTornado, WahooNetBanner, YRabbit окупают свою стоимость уже на 2 день.

# %% [markdown]
# ## Оценка удержания и конверсии
# ### Удержание с разбивкой по устройствам

# %%
# формирование таблиц удержания  и динамики удержания
retention_raw_device, retention_device, retention_history_device = get_retention(profiles, visits, observation_date, horizon, dimensions = ['device'], ignore_horizon = False)

# обзор долей удержания и динамики удержания
display(retention_device)
display(retention_history_device)

# графики удержания и динамики удержания
plot_retention(retention_device, retention_history_device, horizon, window=14)
# Out:
#                cohort_size    0         1         2         3         4  \
# payer device
# 0     Android        18992  1.0  0.175021  0.086510  0.052022  0.031382
#       Mac            16151  1.0  0.179184  0.085691  0.049409  0.033063
#       PC             16922  1.0  0.174684  0.087283  0.052358  0.034570
#       iPhone         29277  1.0  0.178126  0.086826  0.052772  0.034532
# 1     Android         1691  1.0  0.384388  0.298640  0.249556  0.214075
#       Mac             1596  1.0  0.365288  0.283835  0.203008  0.196742
#       PC              1206  1.0  0.422056  0.333333  0.262852  0.262023
#       iPhone          2809  1.0  0.370239  0.277323  0.233891  0.193663
#
#                       5         6         7         8         9        10  \
# payer device
# 0     Android  0.024010  0.017481  0.013901  0.010899  0.009794  0.007635
#       Mac      0.023899  0.019503  0.014550  0.012569  0.009040  0.007801
# ...

# %% [markdown]
# 1. Лучшее из возможных удержаний для платящих пользователей показывает тип устройств PC.
# 2. Удержание неплатящих не зависит от устройства и стабильно низко.
# 3. Удержание 14 дня лучше всего у PC, на втором месте - Mac.

# %% [markdown]
# ### Удержание с разбивкой по странам

# %%
# формирование таблиц удержания  и динамики удержания
retention_raw_region, retention_region, retention_history_region = get_retention(profiles, visits, observation_date, horizon, dimensions = ['region'], ignore_horizon = False)

# обзор долей удержания и динамики удержания
display(retention_region)
display(retention_history_region)

# графики удержания и динамики удержания
plot_retention(retention_region, retention_history_region, horizon, window = 14)
# Out:
#                      cohort_size    0         1         2         3         4  \
# payer region
# 0     France                9994  1.0  0.173004  0.091155  0.052031  0.033720
#       Germany               8563  1.0  0.176690  0.084900  0.056172  0.035034
#       UK                   10003  1.0  0.179046  0.088573  0.051485  0.031990
#       United States        52782  1.0  0.177257  0.085673  0.051173  0.033515
# 1     France                 522  1.0  0.475096  0.386973  0.323755  0.308429
#       Germany                467  1.0  0.483940  0.402570  0.314775  0.327623
#       UK                     533  1.0  0.484053  0.422139  0.326454  0.300188
#       United States         5780  1.0  0.354671  0.263668  0.212803  0.183737
#
#                             5         6         7         8         9  \
# payer region
# 0     France         0.022614  0.018211  0.014609  0.012007  0.010306
#       Germany        0.025225  0.019503  0.014014  0.010394  0.009926
# ...

# %% [markdown]
# 1. Среди платящих пользователей существенно проседает удержание тех, кто из США. Остальные три страны держатся вместе.
# 2. Удержание неплатящих пользователей не зависит от страны и крайне низко.
# 3. Динамика удержания на 14 день выглядит неоднозначно: у США самый низкий, но непрерывный показатель, а у других стран встречаются когорты, где на 14 день не осталось пользователей.

# %% [markdown]
# ### Удержание с разбивкой по рекламным каналам

# %%
# формирование таблиц удержания  и динамики удержания
retention_raw_channel, retention_channel, retention_history_channel = get_retention(profiles, visits, observation_date, horizon, dimensions = ['channel'], ignore_horizon = False)

# обзор долей удержания и динамики удержания
display(retention_channel)
display(retention_history_channel)

# графики удержания и динамики удержания
plot_retention(retention_channel, retention_history_channel, horizon, window=14)
# Out:
#                           cohort_size    0         1         2         3  \
# payer channel
# 0     AdNonSense                 3289  1.0  0.176345  0.087565  0.051079
#       FaceBoom                  24184  1.0  0.173007  0.087248  0.050777
#       LeapBob                    7861  1.0  0.171098  0.091337  0.051393
#       MediaTornado               4019  1.0  0.183130  0.082359  0.056482
#       OppleCreativeMedia         7919  1.0  0.171991  0.089026  0.053416
#       RocketSuperAds             3917  1.0  0.175389  0.085780  0.051570
#       TipTop                    16716  1.0  0.181742  0.084709  0.050849
#       WahooNetBanner             7655  1.0  0.184193  0.085434  0.053037
#       YRabbit                    3946  1.0  0.180182  0.083376  0.049164
#       lambdaMediaAds             1836  1.0  0.183007  0.086601  0.062636
# 1     AdNonSense                  413  1.0  0.285714  0.162228  0.130751
#       FaceBoom                   3360  1.0  0.222321  0.122917  0.075298
# ...

# %% [markdown]
# 1. Ниже всего удержание тех платящих пользователей, которые пришли из каналов FaceBoom и AdNonSense.
# 2. Удержание платящих пользователей не зависитот канала.
# 3. Динамика 14 дня напоминает разбивку по странам: удержание FaceBoom низкое, но непрерывное, а всех других каналов - отрывистое. Далеко не всегда пользователи удерживаются до 14 дня. Исключение- TipTop, и уровень у него заметно лучше FaceBoom.

# %% [markdown]
# ### Конверсия с разбивкой по устройствам

# %%
# формирование таблиц конверсии и динамики конверсии
conversion_raw_device, conversion_device, conversion_history_device = get_conversion(profiles, orders, observation_date, horizon, dimensions=['device'], ignore_horizon=False,)

# обзор конверсии и динамики конверсии
display(conversion_device)
conversion_history_device

# графики конверсии и динамики конверсии
plot_conversion(conversion_device, conversion_history_device, horizon, window=14)
# Out:
#          cohort_size       0.0       1.0       2.0       3.0       4.0  \
# device
# Android        20683  0.058309  0.066141  0.070058  0.072378  0.074506
# Mac            17747  0.064349  0.072970  0.076802  0.079281  0.080971
# PC             18128  0.046613  0.053067  0.055991  0.058142  0.060293
# iPhone         32086  0.062800  0.070249  0.074113  0.077136  0.078944
#
#               5.0       6.0       7.0       8.0       9.0      10.0      11.0  \
# device
# Android  0.075714  0.076923  0.077552  0.078083  0.078760  0.079050  0.079341
# Mac      0.082267  0.083225  0.084014  0.084747  0.085648  0.086268  0.086493
# PC       0.061562  0.062665  0.063438  0.064100  0.064431  0.064707  0.064817
# iPhone   0.080253  0.081001  0.082061  0.082871  0.083526  0.083962  0.084429
#
#              12.0      13.0
# device
# Android  0.079679  0.079824
# Mac      0.086606  0.087001
# PC       0.065038  0.065313
# iPhone   0.084616  0.084928

# %% [markdown]
# 1. Самую низкую конверсию дают приносят пользователи PC - и в целом, и на 14 день.
# 2. Mac и iPhone лидируют в целом, а на 14 с ними способен равнаяться Android.

# %% [markdown]
# ### Конверсия с разбивкой по странам

# %%
# формирование таблиц конверсии и динамики конверсии
conversion_raw_region, conversion_region, conversion_history_region = get_conversion(profiles, orders, observation_date, horizon, dimensions=['region'], ignore_horizon=False,)

# обзор конверсии и динамики конверсии
display(conversion_region)
conversion_history_region

# графики конверсии и динамики конверсии
plot_conversion(conversion_region, conversion_history_region, horizon, window=14)
# Out:
#                cohort_size       0.0       1.0       2.0       3.0       4.0  \
# region
# France               10516  0.033092  0.037467  0.040985  0.042697  0.044313
# Germany               9030  0.032337  0.038760  0.041528  0.043854  0.045072
# UK                   10536  0.034074  0.039104  0.042426  0.044039  0.045368
# United States        58562  0.071873  0.080650  0.084560  0.087497  0.089700
#
#                     5.0       6.0       7.0       8.0       9.0      10.0  \
# region
# France         0.045359  0.046120  0.046405  0.046976  0.047547  0.047642
# Germany        0.046512  0.047398  0.048283  0.049059  0.049612  0.049723
# UK             0.046412  0.047551  0.048121  0.048405  0.048595  0.048975
# United States  0.091032  0.092022  0.093013  0.093798  0.094549  0.095062
#
#                    11.0      12.0      13.0
# region
# France         0.048117  0.048307  0.048402
# Germany        0.049834  0.049945  0.050498
# UK             0.049070  0.049165  0.049165
# ...

# %% [markdown]
# 1. Самую высокую конверсию приносятпользователи из США, оставляя далеко позади остальные страны.
# 2. В конце мая есть одно пересечение на 14 день - Франция сравнялась с США, но в остальном конверсия 14 дня существенно ниже у Франции, Великобритании и Германии.

# %% [markdown]
# ### Конверсия с разбивкой по рекламным каналам

# %%
# формирование таблиц конверсии и динамики конверсии
conversion_raw_channel, conversion_channel, conversion_history_channel = get_conversion(profiles, orders, observation_date, horizon, dimensions=['channel'], ignore_horizon=False,)

# обзор конверсии и динамики конверсии
display(conversion_channel)
conversion_history_channel

# графики конверсии и динамики конверсии
plot_conversion(conversion_channel, conversion_history_channel, horizon, window=14)
# Out:
#                     cohort_size       0.0       1.0       2.0       3.0  \
# channel
# AdNonSense                 3702  0.086980  0.094003  0.096704  0.100486
# FaceBoom                  27544  0.102091  0.109134  0.111494  0.113346
# LeapBob                    8103  0.016660  0.020610  0.024065  0.025052
# MediaTornado               4167  0.023278  0.027358  0.028078  0.029998
# OppleCreativeMedia         8139  0.017324  0.019904  0.021501  0.023099
# RocketSuperAds             4251  0.034110  0.047283  0.053870  0.059280
# TipTop                    18498  0.056709  0.069413  0.076062  0.080711
# WahooNetBanner             8082  0.031180  0.038481  0.043306  0.045038
# YRabbit                    4102  0.025841  0.028766  0.031204  0.032179
# lambdaMediaAds             2056  0.072471  0.081712  0.085117  0.088521
#
#                          4.0       5.0       6.0       7.0       8.0  \
# channel
# AdNonSense          0.102107  0.103998  0.105348  0.105348  0.105889
# ...

# %% [markdown]
# 1. Лидеры общей конверсии среди каналов - FaceBoom, AdNonSense, lambdaMediaAds и TipTop.
# 2. По графикам 14 дня видны по меньшей мере 2 пиковых значения у lambdaMediaAds - в июне и августе.

# %% [markdown]
# ### Промежуточные выводы
# 1. Удержание 14 дня лучше всего у PC, на втором месте — Mac.
# 2. Динамика удержания на 14 день выглядит неоднозначно: у США самый низкий, но непрерывный показатель, а у других стран в стречаются когорты, где на 14 день не осталось пользователей.
# 3. Динамика удержания на 14 день по каналам напоминает разбивку по странам: удержание FaceBoom низкое, но непрерывное, а всех других каналов - отрывистое. Далеко не всегда пользователи удерживаются до 14 дня. Исключение- TipTop, и уровень у него заметно лучше FaceBoom.
# 4. Самую низкую конверсию приносят пользователи PC - и в целом, и на 14 день.
# 5. Mac и iPhone лидируют в целом, а на 14 день с ними способен равнаяться Android.
# 6. Самую высокую конверсию приносят пользователи из США, оставляя далеко позади остальные страны.
# 7. Лидеры общей конверсии среди каналов - FaceBoom, AdNonSense, lambdaMediaAds и TipTop.

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №1__
#
# Анализ не полный, т.к. проблемы могут быть в удержании каналов/стран/устройств/, а без анализа конверсии и удержания, мы не сможем дать рекомендации маркетологам.
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарии студента:</b> Построила графики про конверсию и удержание, прокомментировала их и написала промежуточные выводы.</div>

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №2__
#
# Согласен с интерпретацией результатов. Проблемные источники определены верно.

# %% [markdown]
# ## Основные выводы и рекомендации

# %% [markdown]
# 1. В целом реклама не окупается.
# 2. Привлечение Mac и iPhone – самое дорогое, но и конверсия у этих устройств самая высокая.
# 3. Однако эти устройства плохо удерживаются.
# 4. При этом PC окупаются, хоть и к 12 дню, дают лучшее из возможных удержание и самый низкий показатель CAC.
# 5. Самый высокий показатель LTV по странам — у США, также как и стоимость привлечения (и продолжает расти).
# 6. Но ROI США — самый низкий из всех, этот регион единственный вообще не окупается, и ROI 14 дня уходит в минус уже в мае.
# 7. Аналогично удержание — самое низкое у США, хотя и сохраняется у всех когорт на 14 день, в то время как остальные страны не доходят до 14 дня в некоторых когортах.
# 8. При этом у США — самая высокая конверсия и самая лучшая динамика конверсии на 14 день.
# 9. CAC для большинства каналов не превышает 1 доллар с небольшим, кроме TipTop. Его CAC ступенчато растет и преодолевает отметку 3,5 доллара к концу рассматриваемого периода.
# 10. При этом TipTop не просто не окупается, но занимает самое нижнее место на графике ROI.
# 11. Окупаются – в пределах 6 дней - все каналы кроме FaceBoom, TipTop и AdNonSense.
# 12. FaceBoom и AdNonSense еще и дают самое низкое удержание.
# 13. FaceBoom при этом единственный, кто приводит пользователей, «доживающих» до 14 дня. Другие каналы имеют лакуны в динамике удержания на 14 день.
# 14. При этом каналы FaceBoom, AdNonSense, lambdaMediaAds и TipTop дают самую высокую конверсию.

# %% [markdown]
# ### Рекомендации
# 1. Проанализировать, с чем связано низкое удержание для самых прибыльных устройств. Почему владельцы оных делают хорошие первые покупки, но быстро уходят?
# 2. Изучить, почему PC - единственное окупаемое устройство. Что привлекательно для пользователей PC и может быть адаптировано для Mac и iPhone?
# 3. Снизить стоимость привлечения в США - возможно, оказаться от рекламы в TipTop и перераспределить высвободившийся бюджет между FaceBoom, AdNonSense, lambdaMediaAds и другими окупаемыми каналами.
# 4. Изучить особенности рынка в США - возможно, там есть сильные конкуренты, к которым мигрируют пользователи после первой покупки в Procrastinate Pro+.
# 5. Проанализировать, какие события происходили в приложении и вокруг него в середине каждого месяца с мая по август, а также в начале сентября и октября. В эти моменты мы наблюдаем пиковые значения LTV и CR – возможно, подобный эффект может быть воссоздан и пролонгирован.
# 6. В анализ попали летние месяцы — период отпусков, когда у людей есть масса других забот и интересных дел, чем развлекательные приложения. При этом тип устройства PC — рабочий инструмент — единственный окупается. В связи с этим рекомендуем изучить сезонный фактор — возможно, запускать и продвигать приложение стоит в более оживленное время бизнес-года.

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
# Давай посмотрим на анализ конверсии и удержания для стран / каналов / девайсов и возможно пересмотрим рекомендации?
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарии студента:</b> Полностью переписала выводы и рекомендации. Было трудно, честно говоря, потому что зависимостей много, и иногда они выглядят противоречиво для начинающего аналитика.</div>

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №2__
#
# Хорошо бы ещё в рекомендации добавить каналы, к которым стоит присмотреться с положительной стороны
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
# Комментарий от ревьюера №1 </b>
#
#
#
# У тебя получилась очень сильная и хорошая работа. Здорово, что расчеты ты сопровождаешь иллюстрациями, а так же не забываешь про комментарии, твой проект интересно проверять.
#
# ---
#
# Нужно поправить:
#
# 1) Выгрузка данных
#
# 2) Оформление графиков
#
# 3) После каждого раздела / графика (или серии тестов) писать вывод по полученным данным с учетом поставленной бизнес задачи
#
# 4) Из расчетов нам следует исключить пользователей с органическим трафиком
#
# 5) Конверсия и удержание по метрикам (страны / каналы / девайсы)
#
# 6) Подправить выводы, после изменений
#
# ----
#
#
# Если у тебя будут какие-то вопросы по моим комментариям - обязательно пиши! Буду ждать работу на повторное ревью :)</div>

# %% [markdown]
# <div style="border:solid blue 3px; padding: 20px">
# <div class="alert alert-block alert-success">✔️
#
#
# __Коментарий от ревьюера №2__
#
#
# В остальном всё чудно😊. Твой проект так и просится на github =)
#
# Поздравляю с успешным завершением проекта 😊👍
# И желаю успехов в новых работах 😊
#
# ---
#
# От себя хочу порекомендовать тебе отличный материал про продуктовую аналитику Дмитрия Животворева.
#
# https://www.youtube.com/watch?v=Vy_rq-x9QEo
